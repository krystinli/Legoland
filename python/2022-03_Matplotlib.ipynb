# %% [markdown]
# ## matplotlib
# I want to create a code snippet for common plotting with matplotlib.
#
# Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# sample data
data=[[1,0,1,1,1,0,1,0,],
      [2,1,1,0,0,1,0,0,],
      [3,1,0,0,1,0,0,1,],
      [4,1,0,0,0,0,0,1,],
      [5,0,0,0,0,0,0,0,],]

# convert above data into pd df
df=pd.DataFrame(
    data,
    columns=["Week of the Month","Mon","Tue","Wed","Thu","Fri","Sat","Sun"])

# %%
df["Weekday_Total"] = df["Mon"] + df["Tue"] + df["Wed"] + df["Thu"] + df["Fri"]
df["Weekend_Total"] = df["Sat"] + df["Sun"]
df
# Out:
#    Week of the Month  Mon  Tue  Wed  Thu  Fri  Sat  Sun  Weekday_Total  \
# 0                  1    0    1    1    1    0    1    0              3
# 1                  2    1    1    0    0    1    0    0              3
# 2                  3    1    0    0    1    0    0    1              2
# 3                  4    1    0    0    0    0    0    1              1
# 4                  5    0    0    0    0    0    0    0              0
#
#    Weekend_Total
# 0              1
# 1              0
# 2              1
# 3              1
# 4              0

# %% [markdown]
# ## plt.plot(x-axis, y-axis)

# %%
plt.plot(
    df["Week of the Month"], # x-axis
    df["Weekday_Total"]      # y-axis
)

# %%
plt.plot(
    df["Week of the Month"], # x-axis
    df["Weekday_Total"],     # y-axis
    'o'                      # without the line
)

# %%
# default x-axis
plt.plot(df["Weekday_Total"], 
    
    # marker
    marker = 'o', # marker
    ms = 10, # markersize
    mec = 'hotpink', 
    mfc = 'hotpink',
    
    # line 
    linestyle = 'dotted',
    color = 'b', # line colour
    linewidth = '5'
)

# %%
# multiple lines
plt.plot(df["Weekday_Total"])
plt.plot(df["Weekend_Total"])

# adding titles and labels
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Exercise Tracking", fontdict = font1, loc = 'left')
plt.xlabel("Week of Month", fontdict = font2)
plt.ylabel("Num of Exercise", fontdict = font2)

plt.grid(
    axis = 'x', 
    color = 'grey', 
    linestyle = '--', 
    linewidth = 0.5
)

# %% [markdown]
# ## subplot()
# The subplot() function takes three arguments that describes the layout of the figure.

# %%
# plot 1
plt.subplot(1, 2, 1) # The figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(df["Weekday_Total"])
plt.title("Weekday_Total")

# plot 2
plt.subplot(1, 2, 2)
plt.plot(df["Weekend_Total"])
plt.title("Weekend_Total")

plt.suptitle("Exercise")
# Out:
# Text(0.5, 0.98, 'Exercise')

# %%
# plot 1
plt.subplot(2, 1, 1) # The figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(df["Weekday_Total"])

# plot 2
plt.subplot(2, 1, 2)
plt.plot(df["Weekend_Total"])
# Out:
# Text(0.5, 0.98, 'Exercise')
